# %% [markdown]
# # Robot example in colab

# %% [markdown]
# ## Run the following cells only once when resetting the runtime.

# %%
try:
  import condacolab
  condacolab.check()
except:
  # !pip install -q condacolab
  import condacolab
  condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# # Run the following code to install the packages we will use

# %%
try:
  # Check if packages are installed or not. If not, install them.
  import pinocchio
except:
  # Install the meschat-python and pybullet
  # !conda install pinocchio meshcat-python pybullet

  # Install the NYU_Finger software environment.
  # !pip install git+https://github.com/machines-in-motion/bullet_utils
  # !pip install git+https://github.com/open-dynamic-robot-initiative/robot_properties_nyu_finger/

  # Install the code for writing controllers
  # !pip install git+https://github.com/machines-in-motion/mim_data_utils
  # !pip install git+https://github.com/machines-in-motion/dynamic_graph_head

# %% [markdown]
# # Import all libraries and create meshcat server

# %%
import pinocchio as pin
import numpy as np
np.set_printoptions(precision=3, suppress=True)

from robot_properties_nyu_finger.config import NYUFingerConfig
from robot_properties_nyu_finger.wrapper import NYUFingerRobot
from bullet_utils.env import BulletEnv
import pybullet as p

from dynamic_graph_head import ThreadHead, SimHead, HoldPDController

# Start a single meshcat server instance to use for the remainder of this notebook.
import meshcat
from meshcat.servers.zmqserver import start_zmq_server_as_subprocess
proc, zmq_url, web_url = start_zmq_server_as_subprocess(server_args=['--ngrok_http_tunnel'])

viewer = meshcat.Visualizer(zmq_url=zmq_url)
# Out:
# You can open the visualizer by visiting the following URL:
# http://41c6dde9120a.ngrok.io/static/

# %% [markdown]
# # Initialize the Simulator environment and setup the viewer for the created robot.

# %%
class BulletEnvMeshcat(BulletEnv):
  """ Similar to the normal BulletEnv but updates a visualizer at each step. """

  def set_visualizer(self, viz):
    self._viz = viz

  def step(self, sleep=False):
    super().step(sleep)

    # Hack: Assume the robot we want to visualize is the first one.
    q = bullet_env.robots[0].get_state()[0]
    self._viz.display(q)

# Build the simulator.
bullet_env = BulletEnvMeshcat(p.DIRECT)

# Create a robot instance. This adds the robot to the simulator as well.
robot = NYUFingerRobot()

# Add the robot to the bullet_env to update the internal structure of the robot
# ate every simulation steps.
bullet_env.add_robot(robot)

# Setup the visualizer
viz = pin.visualize.MeshcatVisualizer(
    robot.pin_robot.model, robot.pin_robot.collision_model, robot.pin_robot.visual_model
)
viz.initViewer(viewer)
viz.loadViewerModel()
viz.display(np.array([0.0, 0.0, 0.0]))

bullet_env.set_visualizer(viz)

print('You should see the finger robot now when going to this page:', web_url)
# Out:
# You should see the finger robot now when going to this page: http://41c6dde9120a.ngrok.io/static/

# %%
class PDController:
  def __init__(self, head, Kp_gain, Kd_gain):
    self.head = head
    self.Kp_gain = Kp_gain
    self.Kd_gain = Kd_gain

    self.joint_positions = head.get_sensor('joint_positions')
    self.joint_velocities = head.get_sensor('joint_velocities')

  def warmup(self, thread_head):
    self.desired_pos = self.joint_positions.copy()
    print('=== PDController::warmup')
    print('   self.desired_pos:     ', self.desired_pos)

  def update_desired_pos(self, new_target_pos):
    self.desired_pos = new_target_pos.copy()
    print('=== PDController::update_desired_pos')
    print('   self.desired_pos:     ', self.desired_pos)

  def run(self, thread_head):
    print('=== PDController::Run. ti:', thread_head.ti)
    print('   self.desired_pos:     ', self.desired_pos)
    print('   self.joint_positions: ', self.joint_positions)
    print('   self.joint_velocities:', self.joint_velocities)

    self.tau = (self.Kp_gain * (self.desired_pos - self.joint_positions) - 
                self.Kd_gain * self.joint_velocities)
    head.set_control('ctrl_joint_torques', self.tau)

    print('-> self.tau             :', self.tau)

# %%
# Create a simulated head.
head = SimHead(robot, with_sliders=False)

# Reset initial position of the robot.
head.reset_state([0.0, 0.0, 0.0], [0, 0, 0])

# Create our controllers
ctrl = PDController(head, 3., 0.05)
safety_controller = HoldPDController(head, 3., 0.05, False)

# Initialize the controller infrastructure.
thread_head = ThreadHead(
    0.001, # dt.
    safety_controller, # Safety controllers.
    head, # Heads to read / write from.
    [],   # Utils.
    bullet_env # Environment to step.
)

# %%
# Run simulation for 1000 steps = 1000 ms = 1 s.
thread_head.sim_run(1000)

# %%
thread_head.switch_controllers(ctrl)
ctrl.update_desired_pos(np.array([0, 0.5, -1.0]))
# Out:
# === PDController::warmup
#    self.desired_pos:      [-0.022  0.     0.   ]
# === PDController::Run. ti: 1000
#    self.desired_pos:      [-0.022  0.     0.   ]
#    self.joint_positions:  [-0.022  0.     0.   ]
#    self.joint_velocities: [-0.001  0.     0.   ]
# -> self.tau             : [ 0. -0. -0.]
# === PDController::update_desired_pos
#    self.desired_pos:      [ 0.   0.5 -1. ]

# %%
from google.colab import files

# Run simulation for 100 steps = 100 ms.
thread_head.start_logging()
thread_head.sim_run(100)
log_path = thread_head.stop_logging()

files.download(log_path) 

print("You can inspect your log file using this tool:")
print("")
pritn("    https://machines-in-motion.github.io/mim_data_utils/")
# Out:
#   Not logging 'head' as field type '<class 'dynamic_graph_head.sim_head.SimHead'>' is unsupported
# !!! ThreadHead: Start logging to file "2021-08-02_02-37-43.mds" for 30.00 seconds.
# === PDController::Run. ti: 1000
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.     0.   ]
#    self.joint_velocities: [-0.001  0.     0.   ]
# -> self.tau             : [ 0.067  1.5   -3.   ]
# === PDController::Run. ti: 1001
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.005 -0.015]
#    self.joint_velocities: [ -0.001   4.901 -15.231]
# -> self.tau             : [ 0.067  1.24  -2.193]
# === PDController::Run. ti: 1002
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.013 -0.042]
#    self.joint_velocities: [ -0.018   8.57  -26.544]
# -> self.tau             : [ 0.068  1.031 -1.547]
# === PDController::Run. ti: 1003
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.025 -0.076]
#    self.joint_velocities: [ -0.061  11.244 -34.699]
# -> self.tau             : [ 0.07   0.864 -1.036]
# === PDController::Run. ti: 1004
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.038 -0.117]
#    self.joint_velocities: [ -0.128  13.115 -40.311]
# -> self.tau             : [ 0.074  0.731 -0.634]
# === PDController::Run. ti: 1005
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.023  0.052 -0.161]
#    self.joint_velocities: [ -0.212  14.342 -43.894]
# -> self.tau             : [ 0.079  0.626 -0.323]
# === PDController::Run. ti: 1006
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.023  0.067 -0.207]
#    self.joint_velocities: [ -0.303  15.061 -45.881]
# -> self.tau             : [ 0.084  0.545 -0.086]
# === PDController::Run. ti: 1007
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.023  0.083 -0.253]
#    self.joint_velocities: [ -0.395  15.388 -46.641]
# -> self.tau             : [0.09  0.483 0.092]
# === PDController::Run. ti: 1008
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.024  0.098 -0.3  ]
#    self.joint_velocities: [ -0.481  15.421 -46.479]
# -> self.tau             : [0.096 0.435 0.223]
# === PDController::Run. ti: 1009
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.024  0.113 -0.345]
#    self.joint_velocities: [ -0.558  15.239 -45.648]
# -> self.tau             : [0.101 0.398 0.318]
# === PDController::Run. ti: 1010
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.025  0.128 -0.39 ]
#    self.joint_velocities: [ -0.622  14.907 -44.347]
# -> self.tau             : [0.106 0.37  0.386]
# === PDController::Run. ti: 1011
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.026  0.143 -0.432]
#    self.joint_velocities: [ -0.674  14.475 -42.729]
# -> self.tau             : [0.111 0.348 0.434]
# === PDController::Run. ti: 1012
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.026  0.157 -0.473]
#    self.joint_velocities: [ -0.713  13.98  -40.911]
# -> self.tau             : [0.115 0.331 0.465]
# === PDController::Run. ti: 1013
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.027  0.17  -0.512]
#    self.joint_velocities: [ -0.74   13.451 -38.978]
# -> self.tau             : [0.119 0.317 0.486]
# === PDController::Run. ti: 1014
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.028  0.183 -0.549]
#    self.joint_velocities: [ -0.756  12.908 -36.993]
# -> self.tau             : [0.122 0.306 0.498]
# === PDController::Run. ti: 1015
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.029  0.195 -0.584]
#    self.joint_velocities: [ -0.761  12.363 -34.999]
# -> self.tau             : [0.124 0.296 0.503]
# === PDController::Run. ti: 1016
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.029  0.207 -0.617]
#    self.joint_velocities: [ -0.758  11.828 -33.026]
# -> self.tau             : [0.126 0.287 0.503]
# === PDController::Run. ti: 1017
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.03   0.219 -0.648]
#    self.joint_velocities: [ -0.746  11.308 -31.094]
# -> self.tau             : [0.128 0.279 0.5  ]
# === PDController::Run. ti: 1018
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.031  0.229 -0.678]
#    self.joint_velocities: [ -0.727  10.808 -29.218]
# -> self.tau             : [0.129 0.272 0.494]
# === PDController::Run. ti: 1019
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.032  0.24  -0.705]
#    self.joint_velocities: [ -0.703  10.329 -27.405]
# -> self.tau             : [0.13  0.265 0.485]
# === PDController::Run. ti: 1020
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.032  0.25  -0.731]
#    self.joint_velocities: [ -0.673   9.874 -25.661]
# -> self.tau             : [0.131 0.258 0.475]
# === PDController::Run. ti: 1021
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.033  0.259 -0.755]
#    self.joint_velocities: [ -0.639   9.443 -23.989]
# -> self.tau             : [0.131 0.251 0.463]
# === PDController::Run. ti: 1022
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.034  0.268 -0.777]
#    self.joint_velocities: [ -0.601   9.035 -22.389]
# -> self.tau             : [0.131 0.244 0.451]
# === PDController::Run. ti: 1023
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.034  0.277 -0.798]
#    self.joint_velocities: [ -0.561   8.65  -20.862]
# -> self.tau             : [0.13  0.238 0.437]
# === PDController::Run. ti: 1024
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.035  0.285 -0.817]
#    self.joint_velocities: [ -0.518   8.288 -19.406]
# -> self.tau             : [0.13  0.231 0.422]
# === PDController::Run. ti: 1025
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.035  0.293 -0.835]
#    self.joint_velocities: [ -0.474   7.947 -18.02 ]
# -> self.tau             : [0.129 0.224 0.407]
# === PDController::Run. ti: 1026
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.036  0.301 -0.852]
#    self.joint_velocities: [ -0.429   7.626 -16.703]
# -> self.tau             : [0.128 0.217 0.391]
# === PDController::Run. ti: 1027
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.036  0.308 -0.868]
#    self.joint_velocities: [ -0.383   7.326 -15.453]
# -> self.tau             : [0.127 0.21  0.375]
# === PDController::Run. ti: 1028
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.036  0.315 -0.882]
#    self.joint_velocities: [ -0.336   7.044 -14.267]
# -> self.tau             : [0.126 0.203 0.359]
# === PDController::Run. ti: 1029
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.322 -0.895]
#    self.joint_velocities: [ -0.29    6.779 -13.145]
# -> self.tau             : [0.124 0.196 0.342]
# === PDController::Run. ti: 1030
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.328 -0.907]
#    self.joint_velocities: [ -0.244   6.531 -12.083]
# -> self.tau             : [0.123 0.189 0.325]
# === PDController::Run. ti: 1031
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.334 -0.918]
#    self.joint_velocities: [ -0.198   6.299 -11.08 ]
# -> self.tau             : [0.121 0.182 0.308]
# === PDController::Run. ti: 1032
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.341 -0.928]
#    self.joint_velocities: [ -0.154   6.082 -10.133]
# -> self.tau             : [0.119 0.174 0.291]
# === PDController::Run. ti: 1033
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.346 -0.937]
#    self.joint_velocities: [-0.111  5.879 -9.242]
# -> self.tau             : [0.117 0.167 0.274]
# === PDController::Run. ti: 1034
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.352 -0.946]
#    self.joint_velocities: [-0.069  5.688 -8.403]
# -> self.tau             : [0.115 0.159 0.258]
# === PDController::Run. ti: 1035
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.358 -0.953]
#    self.joint_velocities: [-0.028  5.51  -7.616]
# -> self.tau             : [0.113 0.152 0.241]
# === PDController::Run. ti: 1036
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.363 -0.96 ]
#    self.joint_velocities: [ 0.011  5.344 -6.877]
# -> self.tau             : [0.111 0.144 0.225]
# === PDController::Run. ti: 1037
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.368 -0.967]
#    self.joint_velocities: [ 0.048  5.189 -6.185]
# -> self.tau             : [0.109 0.136 0.209]
# === PDController::Run. ti: 1038
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.373 -0.972]
#    self.joint_velocities: [ 0.083  5.043 -5.538]
# -> self.tau             : [0.107 0.128 0.193]
# === PDController::Run. ti: 1039
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.378 -0.977]
#    self.joint_velocities: [ 0.117  4.908 -4.935]
# -> self.tau             : [0.105 0.12  0.178]
# === PDController::Run. ti: 1040
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.383 -0.981]
#    self.joint_velocities: [ 0.149  4.781 -4.373]
# -> self.tau             : [0.103 0.112 0.163]
# === PDController::Run. ti: 1041
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.388 -0.985]
#    self.joint_velocities: [ 0.179  4.662 -3.851]
# -> self.tau             : [0.101 0.104 0.148]
# === PDController::Run. ti: 1042
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.037  0.392 -0.989]
#    self.joint_velocities: [ 0.207  4.551 -3.367]
# -> self.tau             : [0.099 0.096 0.134]
# === PDController::Run. ti: 1043
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.036  0.397 -0.992]
#    self.joint_velocities: [ 0.233  4.447 -2.919]
# -> self.tau             : [0.097 0.088 0.121]
# === PDController::Run. ti: 1044
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.036  0.401 -0.994]
#    self.joint_velocities: [ 0.257  4.35  -2.505]
# -> self.tau             : [0.095 0.08  0.107]
# === PDController::Run. ti: 1045
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.036  0.405 -0.996]
#    self.joint_velocities: [ 0.28   4.259 -2.124]
# -> self.tau             : [0.093 0.072 0.095]
# === PDController::Run. ti: 1046
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.035  0.409 -0.998]
#    self.joint_velocities: [ 0.301  4.174 -1.774]
# -> self.tau             : [0.091 0.063 0.082]
# === PDController::Run. ti: 1047
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.035  0.413 -0.999]
#    self.joint_velocities: [ 0.32   4.094 -1.454]
# -> self.tau             : [0.09  0.055 0.071]
# === PDController::Run. ti: 1048
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.035  0.417 -1.001]
#    self.joint_velocities: [ 0.337  4.018 -1.161]
# -> self.tau             : [0.088 0.047 0.06 ]
# === PDController::Run. ti: 1049
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.034  0.421 -1.001]
#    self.joint_velocities: [ 0.353  3.947 -0.894]
# -> self.tau             : [0.086 0.038 0.049]
# === PDController::Run. ti: 1050
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.034  0.425 -1.002]
#    self.joint_velocities: [ 0.367  3.88  -0.652]
# -> self.tau             : [0.084 0.03  0.039]
# === PDController::Run. ti: 1051
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.034  0.429 -1.003]
#    self.joint_velocities: [ 0.38   3.816 -0.433]
# -> self.tau             : [0.082 0.022 0.029]
# === PDController::Run. ti: 1052
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.033  0.433 -1.003]
#    self.joint_velocities: [ 0.392  3.756 -0.235]
# -> self.tau             : [0.08  0.014 0.02 ]
# === PDController::Run. ti: 1053
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.033  0.437 -1.003]
#    self.joint_velocities: [ 0.402  3.698 -0.058]
# -> self.tau             : [0.079 0.005 0.011]
# === PDController::Run. ti: 1054
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.033  0.44  -1.003]
#    self.joint_velocities: [0.411 3.643 0.1  ]
# -> self.tau             : [ 0.077 -0.003  0.003]
# === PDController::Run. ti: 1055
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.032  0.444 -1.002]
#    self.joint_velocities: [0.419 3.589 0.241]
# -> self.tau             : [ 0.075 -0.011 -0.005]
# === PDController::Run. ti: 1056
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.032  0.447 -1.002]
#    self.joint_velocities: [0.425 3.538 0.365]
# -> self.tau             : [ 0.074 -0.019 -0.012]
# === PDController::Run. ti: 1057
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.031  0.451 -1.002]
#    self.joint_velocities: [0.431 3.488 0.474]
# -> self.tau             : [ 0.072 -0.027 -0.019]
# === PDController::Run. ti: 1058
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.031  0.454 -1.001]
#    self.joint_velocities: [0.436 3.44  0.57 ]
# -> self.tau             : [ 0.071 -0.035 -0.025]
# === PDController::Run. ti: 1059
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.03   0.458 -1.   ]
#    self.joint_velocities: [0.44  3.393 0.652]
# -> self.tau             : [ 0.069 -0.043 -0.031]
# === PDController::Run. ti: 1060
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.03   0.461 -1.   ]
#    self.joint_velocities: [0.443 3.346 0.723]
# -> self.tau             : [ 0.068 -0.05  -0.037]
# === PDController::Run. ti: 1061
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.029  0.464 -0.999]
#    self.joint_velocities: [0.445 3.3   0.783]
# -> self.tau             : [ 0.066 -0.058 -0.042]
# === PDController::Run. ti: 1062
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.029  0.468 -0.998]
#    self.joint_velocities: [0.447 3.254 0.832]
# -> self.tau             : [ 0.065 -0.065 -0.047]
# === PDController::Run. ti: 1063
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.029  0.471 -0.997]
#    self.joint_velocities: [0.447 3.209 0.873]
# -> self.tau             : [ 0.063 -0.073 -0.052]
# === PDController::Run. ti: 1064
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.028  0.474 -0.996]
#    self.joint_velocities: [0.448 3.164 0.906]
# -> self.tau             : [ 0.062 -0.08  -0.056]
# === PDController::Run. ti: 1065
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.028  0.477 -0.995]
#    self.joint_velocities: [0.447 3.118 0.931]
# -> self.tau             : [ 0.061 -0.087 -0.06 ]
# === PDController::Run. ti: 1066
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.027  0.48  -0.994]
#    self.joint_velocities: [0.447 3.073 0.95 ]
# -> self.tau             : [ 0.059 -0.094 -0.064]
# === PDController::Run. ti: 1067
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.027  0.483 -0.993]
#    self.joint_velocities: [0.445 3.027 0.962]
# -> self.tau             : [ 0.058 -0.101 -0.068]
# === PDController::Run. ti: 1068
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.026  0.486 -0.992]
#    self.joint_velocities: [0.444 2.98  0.969]
# -> self.tau             : [ 0.057 -0.107 -0.071]
# === PDController::Run. ti: 1069
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.026  0.489 -0.992]
#    self.joint_velocities: [0.442 2.933 0.971]
# -> self.tau             : [ 0.056 -0.114 -0.074]
# === PDController::Run. ti: 1070
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.025  0.492 -0.991]
#    self.joint_velocities: [0.439 2.885 0.969]
# -> self.tau             : [ 0.054 -0.12  -0.077]
# === PDController::Run. ti: 1071
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.025  0.495 -0.99 ]
#    self.joint_velocities: [0.436 2.836 0.963]
# -> self.tau             : [ 0.053 -0.126 -0.079]
# === PDController::Run. ti: 1072
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.025  0.498 -0.989]
#    self.joint_velocities: [0.433 2.787 0.954]
# -> self.tau             : [ 0.052 -0.132 -0.082]
# === PDController::Run. ti: 1073
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.024  0.5   -0.988]
#    self.joint_velocities: [0.43  2.737 0.942]
# -> self.tau             : [ 0.051 -0.138 -0.084]
# === PDController::Run. ti: 1074
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.024  0.503 -0.987]
#    self.joint_velocities: [0.427 2.686 0.927]
# -> self.tau             : [ 0.05  -0.143 -0.086]
# === PDController::Run. ti: 1075
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.023  0.506 -0.986]
#    self.joint_velocities: [0.423 2.633 0.91 ]
# -> self.tau             : [ 0.049 -0.149 -0.088]
# === PDController::Run. ti: 1076
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.023  0.508 -0.985]
#    self.joint_velocities: [0.419 2.58  0.891]
# -> self.tau             : [ 0.048 -0.154 -0.09 ]
# === PDController::Run. ti: 1077
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.511 -0.984]
#    self.joint_velocities: [0.415 2.526 0.87 ]
# -> self.tau             : [ 0.047 -0.158 -0.091]
# === PDController::Run. ti: 1078
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.513 -0.983]
#    self.joint_velocities: [0.41  2.471 0.848]
# -> self.tau             : [ 0.046 -0.163 -0.093]
# === PDController::Run. ti: 1079
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.022  0.516 -0.982]
#    self.joint_velocities: [0.406 2.415 0.825]
# -> self.tau             : [ 0.045 -0.168 -0.094]
# === PDController::Run. ti: 1080
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.021  0.518 -0.982]
#    self.joint_velocities: [0.401 2.358 0.801]
# -> self.tau             : [ 0.044 -0.172 -0.095]
# === PDController::Run. ti: 1081
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.021  0.52  -0.981]
#    self.joint_velocities: [0.396 2.3   0.776]
# -> self.tau             : [ 0.043 -0.176 -0.096]
# === PDController::Run. ti: 1082
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.02   0.523 -0.98 ]
#    self.joint_velocities: [0.392 2.241 0.75 ]
# -> self.tau             : [ 0.042 -0.18  -0.097]
# === PDController::Run. ti: 1083
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.02   0.525 -0.979]
#    self.joint_velocities: [0.387 2.181 0.724]
# -> self.tau             : [ 0.041 -0.183 -0.098]
# === PDController::Run. ti: 1084
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.02   0.527 -0.979]
#    self.joint_velocities: [0.381 2.12  0.698]
# -> self.tau             : [ 0.04  -0.186 -0.099]
# === PDController::Run. ti: 1085
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.019  0.529 -0.978]
#    self.joint_velocities: [0.376 2.059 0.672]
# -> self.tau             : [ 0.039 -0.19  -0.1  ]
# === PDController::Run. ti: 1086
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.019  0.531 -0.977]
#    self.joint_velocities: [0.371 1.996 0.645]
# -> self.tau             : [ 0.038 -0.192 -0.1  ]
# === PDController::Run. ti: 1087
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.019  0.533 -0.977]
#    self.joint_velocities: [0.365 1.933 0.618]
# -> self.tau             : [ 0.038 -0.195 -0.101]
# === PDController::Run. ti: 1088
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.018  0.535 -0.976]
#    self.joint_velocities: [0.36  1.869 0.591]
# -> self.tau             : [ 0.037 -0.197 -0.101]
# === PDController::Run. ti: 1089
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.018  0.536 -0.976]
#    self.joint_velocities: [0.354 1.804 0.565]
# -> self.tau             : [ 0.036 -0.2   -0.102]
# === PDController::Run. ti: 1090
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.018  0.538 -0.975]
#    self.joint_velocities: [0.349 1.739 0.538]
# -> self.tau             : [ 0.035 -0.202 -0.102]
# === PDController::Run. ti: 1091
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.017  0.54  -0.975]
#    self.joint_velocities: [0.343 1.673 0.512]
# -> self.tau             : [ 0.034 -0.203 -0.102]
# === PDController::Run. ti: 1092
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.017  0.541 -0.974]
#    self.joint_velocities: [0.337 1.607 0.486]
# -> self.tau             : [ 0.034 -0.205 -0.102]
# === PDController::Run. ti: 1093
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.017  0.543 -0.974]
#    self.joint_velocities: [0.331 1.54  0.46 ]
# -> self.tau             : [ 0.033 -0.206 -0.102]
# === PDController::Run. ti: 1094
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.016  0.545 -0.973]
#    self.joint_velocities: [0.325 1.472 0.434]
# -> self.tau             : [ 0.032 -0.207 -0.102]
# === PDController::Run. ti: 1095
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.016  0.546 -0.973]
#    self.joint_velocities: [0.319 1.404 0.409]
# -> self.tau             : [ 0.032 -0.208 -0.102]
# === PDController::Run. ti: 1096
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.016  0.547 -0.972]
#    self.joint_velocities: [0.312 1.336 0.384]
# -> self.tau             : [ 0.031 -0.209 -0.102]
# === PDController::Run. ti: 1097
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.015  0.549 -0.972]
#    self.joint_velocities: [0.306 1.268 0.36 ]
# -> self.tau             : [ 0.031 -0.209 -0.102]
# === PDController::Run. ti: 1098
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.015  0.55  -0.972]
#    self.joint_velocities: [0.3   1.199 0.335]
# -> self.tau             : [ 0.03  -0.209 -0.102]
# === PDController::Run. ti: 1099
#    self.desired_pos:      [ 0.   0.5 -1. ]
#    self.joint_positions:  [-0.015  0.551 -0.971]
#    self.joint_velocities: [0.293 1.13  0.311]
# -> self.tau             : [ 0.029 -0.209 -0.102]
# !!! ThreadHead: Stop logging to file "/content/2021-08-02_02-37-43.mds".
# You can inspect your log file using this tool:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3087fe542bb6> in <module>()
#      10 print("You can inspect your log file using this tool:")
#      11 print("")
# ---> 12 pritn("    https://machines-in-motion.github.io/mim_data_utils/")
#
# NameError: name 'pritn' is not defined
